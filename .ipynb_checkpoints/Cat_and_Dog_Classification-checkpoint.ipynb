# %%
# !pip install numpy -q
# !pip install pandas -q
# !pip install matplotlib -q
# !pip install tensorflow -q

# !pip install opendatasets -q

# %% [markdown]
# # **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/tongpython/cat-and-dog")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: dinidulochana
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/tongpython/cat-and-dog
# Downloading cat-and-dog.zip to ./cat-and-dog
# 100%|██████████| 218M/218M [00:01<00:00, 192MB/s]

# %%
Batch_size = 32
Image_size = (128,128)

# %%
train_data_dir = "/content/cat-and-dog/training_set/training_set"
test_data_dir = "/content/cat-and-dog/test_set/test_set"

# %%
train_data = tf.keras.utils.image_dataset_from_directory(train_data_dir,
                                                       image_size = Image_size,
                                                       batch_size = Batch_size,
                                                       subset = 'training',
                                                       validation_split = 0.1,
                                                       seed = 42)

validation_data = tf.keras.utils.image_dataset_from_directory(train_data_dir,
                                                       image_size = Image_size,
                                                       batch_size = Batch_size,
                                                       subset = 'validation',
                                                       validation_split = 0.1,
                                                       seed = 42)
# Out:
# Found 8005 files belonging to 2 classes.
# Using 7205 files for training.
# Found 8005 files belonging to 2 classes.
# Using 800 files for validation.

# %%
test_data = tf.keras.utils.image_dataset_from_directory(test_data_dir,
                                                       image_size = Image_size,
                                                       batch_size = Batch_size)
# Out:
# Found 2023 files belonging to 2 classes.

# %% [markdown]
# # **Dataset Description**

# %%
class_names = train_data.class_names
class_names
# Out:
# ['cats', 'dogs']

# %%
for image_batch,label_batch in train_data.take(1):
  print(image_batch.shape)
  print(label_batch.shape)
# Out:
# (32, 128, 128, 3)
# (32,)

# %%
plt.figure(figsize=(10,4))
for image,label in train_data.take(1):
  for i in range(12):
    ax = plt.subplot(2,6,i+1)
    plt.imshow(image[i].numpy().astype("uint8"))
    plt.title(class_names[label[i]])
    plt.axis("off")

# %% [markdown]
# # **Data Preprocessing**

# %%
for image,label in train_data.take(1):
  for i in range(1):
    print(image)
# Out:
# tf.Tensor(
# [[[[227.95229   235.95229   248.91356  ]
#    [230.13911   238.13911   249.13911  ]
#    [221.26953   230.26953   239.26953  ]
#    ...
#    [214.03568   221.21146   228.09036  ]
#    [203.23047   212.67969   226.33203  ]
#    [217.91696   227.36618   240.96043  ]]
#
#   [[213.65524   221.65524   234.65524  ]
#    [210.        218.        229.       ]
#    [212.61606   221.61606   230.61606  ]
#    ...
#    [210.92683   217.92683   225.92683  ]
#    [186.36177   195.36177   203.66646  ]
#    [191.98476   200.98476   209.28944  ]]
#
#   [[213.        221.        234.       ]
#    [213.        221.        232.       ]
#    [213.        222.        231.       ]
#    ...
#    [163.92838   168.32594   179.39626  ]
#    [161.15009   167.4118    176.15009  ]
#    [149.52092   155.78264   164.52092  ]]
#
#   ...
#
#   [[115.046036  118.53822    87.78432  ]
#    [176.96849   180.99445   148.0204   ]
#    [143.98785   145.53893   107.2231   ]
#    ...
#    [141.9365    155.22469   101.09274  ]
#    [127.72743   129.8329     82.8329   ]
#    [138.38895   146.45926    97.35379  ]]
#
#   [[160.6501    151.92896   113.99486  ]
#    [143.49683   142.15005   101.63985  ]
#    [144.0783    150.90251   106.90251  ]
#    ...
#    [110.05339   122.5757     75.54028  ]
#    [117.54651   127.06213    77.37312  ]
#    [122.57674   135.97467    85.21686  ]]
#
#   [[159.51088   146.51088   103.37773  ]
#    [134.44481   125.17969    88.424774 ]
#    [157.47963   151.92969   118.75781  ]
#    ...
#    [116.901505  142.1289     82.537674 ]
#    [165.74597   183.84753   128.40222  ]
#    [ 97.126175  115.10681    66.29805  ]]]
#
#
#  [[[255.        255.        255.       ]
#    [255.        255.        255.       ]
#    [255.        255.        255.       ]
#    ...
#    [255.        255.        255.       ]
#    [255.        255.        255.       ]
#    [255.        255.        255.       ]]
#
#   [[255.        255.        255.       ]
#    [255.        255.        255.       ]
#    [255.        255.        255.       ]
#    ...
#    [255.        255.        255.       ]
#    [255.        255.        255.       ]
#    [255.        255.        255.       ]]
#
#   [[255.        255.        255.       ]
#    [255.        255.        255.       ]
#    [255.        255.        255.       ]
#    ...
#    [255.        255.        255.       ]
#    [255.        255.        255.       ]
#    [255.        255.        255.       ]]
#
#   ...
#
#   [[ 89.20697    88.51166    96.51166  ]
#    [125.992065  125.992065  135.406    ]
#    [149.55109   153.55109   164.85858  ]
#    ...
#    [239.69391   246.34875   240.14703  ]
#    [232.69519   239.69519   231.92175  ]
#    [224.4635    231.4635    223.53253  ]]
#
#   [[ 88.62964    88.23901    93.59839  ]
#    [110.86853   111.261536  118.05365  ]
#    [134.03125   138.19135   148.10553  ]
#    ...
#    [251.15228   254.64832   252.50397  ]
#    [250.607     255.        251.607    ]
#    [249.53827   254.53827   249.6148   ]]
#
#   [[105.44531   105.88568   106.859375 ]
#    [116.86017   117.89844   121.611755 ]
#    [134.37885   139.0885    145.00641  ]
#    ...
#    [254.        255.        255.       ]
#    [253.55469   255.        254.55469  ]
#    [253.24506   254.69037   254.24506  ]]]
#
#
#  [[[ 82.399994   82.34656    98.09796  ]
#    [ 46.429993   45.17218    56.22296  ]
#    [ 38.121887   38.27188    41.54767  ]
#    ...
#    [ 75.61014    85.61014    76.61014  ]
#    [ 69.14047    79.14047    70.14047  ]
#    [ 99.785     109.785     100.785    ]]
#
#   [[ 63.08249    70.30109    86.55499  ]
#    [ 67.99173    76.91797    86.36374  ]
#    [ 20.33908    27.342224   28.28363  ]
#    ...
#    [ 71.73276    81.73276    72.73276  ]
#    [ 61.57904    71.57904    62.57904  ]
#    [112.015015  122.015015  113.015015 ]]
#
#   [[ 74.63983    87.63983   106.37109  ]
#    [ 57.999146   71.21008    81.05383  ]
#    [ 37.207367   46.65265    46.707336 ]
#    ...
#    [ 64.453125   74.453125   65.453125 ]
#    [ 56.015533   66.01553    57.015533 ]
#    [108.72189   118.72189   109.72189  ]]
#
#   ...
#
#   [[ 80.787476  103.49841   121.642944 ]
#    [ 82.38138   101.01419   120.80325  ]
#    [ 91.55069   108.69522   128.69522  ]
#    ...
#    [ 11.300751   11.300751   11.300751 ]
#    [ 11.066406   11.066406   11.066406 ]
#    [ 19.514069   19.514069   19.514069 ]]
#
#   [[ 82.207184  100.207184  120.207184 ]
#    [ 91.555145  111.92233   131.13327  ]
#    [ 87.082886  109.23285   127.65787  ]
#    ...
#    [ 18.960175   18.960175   18.960175 ]
#    [ 20.324219   20.324219   20.324219 ]
#    [ 24.30484    24.30484    24.30484  ]]
#
#   [[ 62.627502   78.317505   98.9725   ]
#    [ 85.93405   106.30124   125.51218  ]
#    [ 80.20624   106.854675  123.854675 ]
#    ...
#    [ 22.84845    22.84845    22.84845  ]
#    [ 25.257812   25.257812   25.257812 ]
#    [ 24.257812   24.257812   24.257812 ]]]
#
#
#  ...
#
#
#  [[[208.20886   178.11511   171.75574  ]
#    [193.88452   165.8064    155.16577  ]
#    [226.07922   185.34485   184.14172  ]
#    ...
#    [ 17.039062   12.0390625   9.0390625]
#    [ 17.039062   12.0390625   9.0390625]
#    [ 12.         11.          9.       ]]
#
#   [[221.51697   190.05762   183.69824  ]
#    [217.85693   189.21326   178.57263  ]
#    [206.77893   166.04456   164.84143  ]
#    ...
#    [ 16.882812   11.8828125   7.8828125]
#    [ 16.882812   11.8828125   7.8828125]
#    [ 15.8828125  11.8828125   9.1171875]]
#
#   [[213.16174   179.068     173.70862  ]
#    [224.55664   194.97034   184.6189   ]
#    [233.41394   193.67957   192.47644  ]
#    ...
#    [ 21.804688   14.8046875   8.8046875]
#    [ 21.804688   14.8046875   8.8046875]
#    [ 18.         13.          9.       ]]
#
#   ...
#
#   [[ 16.195312   15.8046875  18.390625 ]
#    [ 16.         16.         18.       ]
#    [ 15.265625   15.265625   16.97876  ]
#    ...
#    [ 16.830322   11.674683    7.7265625]
#    [ 13.499756   14.359375    8.429565 ]
#    [ 15.         14.         11.822998 ]]
#
#   [[ 18.400024   12.751587   22.528198 ]
#    [ 19.359375   19.359375   18.640625 ]
#    [ 13.9375     18.9375     14.703125 ]
#    ...
#    [ 18.562378   13.031128    8.499878 ]
#    [ 18.075073   13.075073    9.715698 ]
#    [ 15.453125   12.453125    7.453125 ]]
#
#   [[ 19.465088   19.500488   21.447388 ]
#    [ 23.28894    28.701416   20.53418  ]
#    [ 20.06482    32.08557    19.99707  ]
#    ...
#    [ 19.796875   14.265625    9.734375 ]
#    [ 19.640625   14.640625   11.28125  ]
#    [ 16.492188   13.4921875   8.4921875]]]
#
#
#  [[[162.39493   194.90729   117.8754   ]
#    [159.05878   194.8967    105.17609  ]
#    [136.54266   178.2497     69.52173  ]
#    ...
#    [152.5047    165.53275   182.60767  ]
#    [141.65811   156.91983   177.05853  ]
#    [138.84573   156.93558   178.75198  ]]
#
#   [[103.75702   138.66718    45.77655  ]
#    [152.77585   192.23065    87.03552  ]
#    [134.08383   178.0643     57.4393   ]
#    ...
#    [127.750916  128.37561   127.26984  ]
#    [134.58035   135.3363    136.25018  ]
#    [134.54892   136.53528   138.72073  ]]
#
#   [[138.91397   179.64835    63.191315 ]
#    [137.40686   181.66647    56.99881  ]
#    [158.88559   206.8899     71.2688   ]
#    ...
#    [158.03833   138.56958   124.38599  ]
#    [139.65057   118.966675  103.49191  ]
#    [140.3787    117.542755   99.991974 ]]
#
#   ...
#
#   [[148.44284   164.65057    93.4187   ]
#    [158.68073   176.40338   102.038605 ]
#    [168.06204   187.67883   108.06204  ]
#    ...
#    [148.60767   184.74008    95.92447  ]
#    [102.628876  140.53302    47.089813 ]
#    [ 78.03427   112.03427    25.850677 ]]
#
#   [[111.07321   119.53415    54.35446  ]
#    [132.29593   142.92111    73.61438  ]
#    [125.03253   139.0109     61.66684  ]
#    ...
#    [ 86.33136   119.31213    38.60269  ]
#    [165.186     197.38522   112.36774  ]
#    [106.39795   138.03857    53.483948 ]]
#
#   [[181.72086   180.72086   113.720856 ]
#    [175.05042   179.05042   105.050415 ]
#    [103.9957    116.08945    33.948822 ]
#    ...
#    [166.92313   199.94656   120.99344  ]
#    [152.09055   175.50461    96.33273  ]
#    [138.53265   161.92328    79.72797  ]]]
#
#
#  [[[ 44.279297   80.2793     34.279297 ]
#    [ 59.98584    95.98584    49.98584  ]
#    [ 57.25537    93.25537    47.25537  ]
#    ...
#    [ 85.2113    122.51465    77.8064   ]
#    [ 64.174805  101.72168    56.081055 ]
#    [ 77.372314  114.91919    69.278564 ]]
#
#   [[ 56.57202    92.57202    47.29077  ]
#    [ 46.692627   82.69263    37.411377 ]
#    [ 59.450806   95.450806   50.169556 ]
#    ...
#    [ 36.983887   73.98389    32.273193 ]
#    [ 89.55798   126.55798    84.27673  ]
#    [ 61.243042   98.24304    55.961792 ]]
#
#   [[ 68.005615  103.005615   61.536865 ]
#    [ 73.95056   108.95056    67.48181  ]
#    [ 82.90198   117.90198    76.43323  ]
#    ...
#    [ 87.01355   122.747925   87.5448   ]
#    [ 61.095825   96.8302     61.627075 ]
#    [ 94.33801   130.07239    94.86926  ]]
#
#   ...
#
#   [[ 51.65381    92.85693    45.12256  ]
#    [ 83.822266  122.822266   75.822266 ]
#    [ 96.29651   133.29651    90.29651  ]
#    ...
#    [ 34.211304   64.543945   19.287231 ]
#    [ 30.419434   60.21631    13.950684 ]
#    [ 39.59485    69.39172    23.433228 ]]
#
#   [[ 88.21533   133.12622    84.12622  ]
#    [ 80.144165  122.144165   74.144165 ]
#    [ 71.728516  108.728516   65.728516 ]
#    ...
#    [ 44.28772    70.93237    27.022339 ]
#    [ 14.229248   40.588623    0.3116455]
#    [ 42.349487   68.70886    23.708862 ]]
#
#   [[100.93396   138.6449     92.512085 ]
#    [ 76.17883   113.17883    70.17883  ]
#    [ 69.80896   105.80896    69.80896  ]
#    ...
#    [ 32.71692    65.71692    18.716919 ]
#    [ 12.040405   41.89685     3.541626 ]
#    [ 64.365845   97.365845   50.365845 ]]]], shape=(32, 128, 128, 3), dtype=float32)

# %%
train_data = train_data.map(lambda x,y : (x/255,y))
validation_data = validation_data.map(lambda x,y : (x/255,y))
test_data = test_data.map(lambda x,y : (x/255,y))

# %%
for image,label in train_data.take(1):
  for i in range(1):
    print(image)
# Out:
# tf.Tensor(
# [[[[0.33503622 0.36991674 0.36723596]
#    [0.42458174 0.45595428 0.46379742]
#    [0.4147875  0.44409204 0.46206078]
#    ...
#    [0.33555454 0.07814786 0.1428206 ]
#    [0.35196546 0.10472747 0.1713313 ]
#    [0.34928566 0.11754546 0.18804178]]
#
#   [[0.38340682 0.41828734 0.41560656]
#    [0.39786005 0.4292326  0.43707573]
#    [0.401447   0.43075153 0.4487203 ]
#    ...
#    [0.28808916 0.10912188 0.1871472 ]
#    [0.3059836  0.14978087 0.22997855]
#    [0.2577681  0.13990659 0.2105239 ]]
#
#   [[0.37206912 0.40694964 0.40426886]
#    [0.42226574 0.4536383  0.46148142]
#    [0.38286552 0.41217005 0.4301388 ]
#    ...
#    [0.09459683 0.03303127 0.12276779]
#    [0.18588915 0.1475848  0.24141164]
#    [0.42293176 0.42452487 0.50729144]]
#
#   ...
#
#   [[0.14467163 0.18047377 0.17100686]
#    [0.19738734 0.23625094 0.21755467]
#    [0.19790219 0.23161574 0.20366473]
#    ...
#    [0.11177057 0.31365752 0.34909502]
#    [0.17935851 0.40862486 0.37733644]
#    [0.22516347 0.37726715 0.33587372]]
#
#   [[0.24286464 0.30265322 0.37788147]
#    [0.196237   0.26825455 0.31066248]
#    [0.15865897 0.21223599 0.21862386]
#    ...
#    [0.11040985 0.3300561  0.39379668]
#    [0.10078855 0.34589592 0.35445437]
#    [0.1781572  0.35755208 0.3474418 ]]
#
#   [[0.1995767  0.28978246 0.4154565 ]
#    [0.20570163 0.2974249  0.3879749 ]
#    [0.13784982 0.21017408 0.24503928]
#    ...
#    [0.12432849 0.34906808 0.4417611 ]
#    [0.07432598 0.33566022 0.38414365]
#    [0.18526503 0.38685662 0.40404975]]]
#
#
#  [[[0.5846418  0.5276493  0.46690825]
#    [0.5803083  0.53255206 0.469807  ]
#    [0.456853   0.4215589  0.3548922 ]
#    ...
#    [0.44633234 0.4502539  0.3247637 ]
#    [0.31064728 0.32633355 0.1969218 ]
#    [0.3943348  0.4178642  0.28453088]]
#
#   [[0.64401627 0.59777015 0.52873635]
#    [0.63477856 0.5998674  0.5265371 ]
#    [0.57379544 0.5455381  0.47102836]
#    ...
#    [0.40361938 0.40505934 0.28080994]
#    [0.30481508 0.31564924 0.18785484]
#    [0.3718048  0.3885634  0.25861546]]
#
#   [[0.53385836 0.4991714  0.41792327]
#    [0.5455325  0.5233874  0.43738303]
#    [0.50625604 0.4866482  0.4003737 ]
#    ...
#    [0.40525794 0.40133637 0.28368932]
#    [0.37035707 0.37427863 0.25271   ]
#    [0.38254836 0.39431307 0.27274445]]
#
#   ...
#
#   [[0.333234   0.2985986  0.23061451]
#    [0.43683165 0.40219626 0.33421218]
#    [0.37432724 0.33969182 0.27170774]
#    ...
#    [0.5163038  0.42805037 0.35659504]
#    [0.43460184 0.35466087 0.28007865]
#    [0.3572045  0.32102373 0.23191343]]
#
#   [[0.36906582 0.33769327 0.26318347]
#    [0.4739837  0.44261116 0.36810136]
#    [0.32125273 0.2898802  0.21537039]
#    ...
#    [0.41027874 0.35081184 0.27231917]
#    [0.45010927 0.40082923 0.31804737]
#    [0.33352798 0.33378115 0.23568791]]
#
#   [[0.4115888  0.3914601  0.29328302]
#    [0.36329293 0.34386167 0.24246766]
#    [0.4701221  0.44999343 0.35289234]
#    ...
#    [0.40532064 0.38260683 0.27926737]
#    [0.42388532 0.3783801  0.2826927 ]
#    [0.3239004  0.32644144 0.21392074]]]
#
#
#  [[[0.1994897  0.19164656 0.2112544 ]
#    [0.20134899 0.19350585 0.2131137 ]
#    [0.17944719 0.17160405 0.1912119 ]
#    ...
#    [0.70676655 0.7310925  0.77134985]
#    [0.69937146 0.7346656  0.7699597 ]
#    [0.70373774 0.719424   0.76648283]]
#
#   [[0.1256879  0.11784477 0.1374526 ]
#    [0.13646647 0.12862334 0.14823118]
#    [0.18641478 0.17857163 0.19817948]
#    ...
#    [0.71516544 0.7394914  0.7797488 ]
#    [0.70916057 0.7444547  0.7797488 ]
#    [0.71485907 0.73054534 0.77760416]]
#
#   [[0.21580452 0.20796138 0.22756922]
#    [0.2124081  0.20456494 0.2241728 ]
#    [0.23776329 0.22992015 0.24952799]
#    ...
#    [0.72336715 0.7476931  0.78795046]
#    [0.71696013 0.75225425 0.78754836]
#    [0.7227592  0.73844546 0.7855043 ]]
#
#   ...
#
#   [[0.23137255 0.2        0.19215687]
#    [0.22745098 0.20925245 0.19748774]
#    [0.22640932 0.21384804 0.20104167]
#    ...
#    [0.3304228  0.33434436 0.31081495]
#    [0.32331496 0.32723653 0.3037071 ]
#    [0.31421137 0.30244666 0.27499568]]
#
#   [[0.23137255 0.2        0.19215687]
#    [0.22745098 0.20925245 0.19748774]
#    [0.22640932 0.21384804 0.20104167]
#    ...
#    [0.319087   0.32300857 0.29947916]
#    [0.31262255 0.31654412 0.2930147 ]
#    [0.31122902 0.29817757 0.27136996]]
#
#   [[0.21307684 0.194031   0.19557771]
#    [0.22352941 0.20784314 0.20392157]
#    [0.22248775 0.20784314 0.1939951 ]
#    ...
#    [0.31084558 0.30692402 0.28731617]
#    [0.31262255 0.30870098 0.28909314]
#    [0.2938831  0.28780112 0.25061274]]]
#
#
#  ...
#
#
#  [[[0.6431373  0.627451   0.5803922 ]
#    [0.6431373  0.627451   0.5803922 ]
#    [0.6380821  0.6223958  0.575337  ]
#    ...
#    [0.18710172 0.10474878 0.03808211]
#    [0.20481005 0.12245711 0.05579044]
#    [0.19620182 0.11384888 0.04136113]]
#
#   [[0.6431373  0.627451   0.5803922 ]
#    [0.6431373  0.627451   0.5803922 ]
#    [0.62858456 0.6128983  0.56583947]
#    ...
#    [0.18710172 0.10474878 0.03808211]
#    [0.20481005 0.12245711 0.05579044]
#    [0.2020229  0.11966996 0.04718221]]
#
#   [[0.64705884 0.6313726  0.58431375]
#    [0.6401042  0.6244179  0.5773591 ]
#    [0.6313726  0.6156863  0.5686275 ]
#    ...
#    [0.18710172 0.10474878 0.03808211]
#    [0.20481005 0.12245711 0.05579044]
#    [0.2032053  0.12085236 0.04836462]]
#
#   ...
#
#   [[0.6559631  0.62555563 0.5732045 ]
#    [0.62728393 0.60146785 0.55854505]
#    [0.5865962  0.5686976  0.55078447]
#    ...
#    [0.7694119  0.71450996 0.6713727 ]
#    [0.7127604  0.65785843 0.6147212 ]
#    [0.7393721  0.6902912  0.6442434 ]]
#
#   [[0.6007055  0.57236606 0.5621485 ]
#    [0.5704044  0.55079657 0.53300136]
#    [0.57063144 0.56772363 0.5299368 ]
#    ...
#    [0.750486   0.69558406 0.6524468 ]
#    [0.70676833 0.6518664  0.6087291 ]
#    [0.6976426  0.6485617  0.6025139 ]]
#
#   [[0.5858969  0.5741322  0.5423614 ]
#    [0.5633425  0.55373776 0.51196384]
#    [0.5724878  0.56464463 0.51491666]
#    ...
#    [0.5084902  0.43915442 0.39993873]
#    [0.5100933  0.43990418 0.4006885 ]
#    [0.5142844  0.4454578  0.4062421 ]]]
#
#
#  [[[0.74088144 0.7678103  0.7190518 ]
#    [0.6226177  0.66949666 0.62243193]
#    [0.57048756 0.62040114 0.54577863]
#    ...
#    [0.16064645 0.17633273 0.12143076]
#    [0.16214767 0.16999081 0.11901042]
#    [0.13374694 0.14745776 0.06086091]]
#
#   [[0.8625558  0.9033474  0.8715612 ]
#    [0.7268916  0.78856784 0.75865644]
#    [0.6523121  0.7204548  0.6707765 ]
#    ...
#    [0.16480766 0.18049394 0.12208401]
#    [0.15174632 0.15958945 0.1051011 ]
#    [0.12785123 0.16253063 0.07351212]]
#
#   [[0.9541153  0.99320626 0.98332787]
#    [0.83045787 0.9084395  0.9017201 ]
#    [0.6439327  0.7303133  0.7114748 ]
#    ...
#    [0.14891352 0.16459979 0.09793312]
#    [0.15385485 0.16561955 0.09895289]
#    [0.11979166 0.16156556 0.07273284]]
#
#   ...
#
#   [[0.32235315 0.36872265 0.35445887]
#    [0.35766476 0.4133415  0.39010757]
#    [0.3735589  0.41868758 0.37850684]
#    ...
#    [0.04673599 0.05117726 0.0258448 ]
#    [0.17147534 0.1753969  0.11537853]
#    [0.3082774  0.3307345  0.19898227]]
#
#   [[0.33201396 0.3729913  0.33945882]
#    [0.32034212 0.37404922 0.34659824]
#    [0.36732092 0.41836262 0.36931238]
#    ...
#    [0.03044595 0.03732402 0.00563965]
#    [0.15906821 0.16298978 0.10808782]
#    [0.46652976 0.4880544  0.43023598]]
#
#   [[0.29688966 0.337867   0.30433452]
#    [0.32068014 0.37438726 0.3469363 ]
#    [0.34206495 0.3931066  0.34405637]
#    ...
#    [0.04217218 0.04905025 0.00880821]
#    [0.47960886 0.48353043 0.42862847]
#    [0.05654716 0.06456077 0.09133642]]]
#
#
#  [[[0.5058824  0.50980395 0.4862745 ]
#    [0.50980395 0.5137255  0.49019608]
#    [0.5137255  0.5176471  0.49411765]
#    ...
#    [0.61599267 0.51344913 0.42991728]
#    [0.6238663  0.5165136  0.46351102]
#    [0.6389451  0.52576077 0.49838653]]
#
#   [[0.5058824  0.50980395 0.4862745 ]
#    [0.50980395 0.5137255  0.49019608]
#    [0.5137255  0.5176471  0.49411765]
#    ...
#    [0.5877604  0.49653858 0.44315436]
#    [0.6162691  0.52663946 0.46152067]
#    [0.63045317 0.53852624 0.46165735]]
#
#   [[0.5058824  0.50980395 0.4862745 ]
#    [0.50980395 0.5137255  0.49019608]
#    [0.5137255  0.5176471  0.49411765]
#    ...
#    [0.602065   0.52149516 0.5063542 ]
#    [0.60689396 0.53253675 0.4688425 ]
#    [0.6223444  0.5521955  0.45025   ]]
#
#   ...
#
#   [[0.84203434 0.86556375 0.8216605 ]
#    [0.81894857 0.842478   0.79857475]
#    [0.80784315 0.83137256 0.7874694 ]
#    ...
#    [0.8268904  0.84226424 0.80389106]
#    [0.79307836 0.8078155  0.7701776 ]
#    [0.75321203 0.763174   0.73105085]]
#
#   [[0.8140165  0.83754593 0.79833025]
#    [0.79937196 0.82290137 0.7836857 ]
#    [0.7978094  0.82133883 0.78212315]
#    ...
#    [0.8113511  0.8152727  0.7917433 ]
#    [0.7868413  0.79076284 0.76723343]
#    [0.7698376  0.7737592  0.7502298 ]]
#
#   [[0.8528085  0.8763379  0.8371222 ]
#    [0.8426777  0.8662071  0.82699144]
#    [0.8445619  0.8680913  0.8288756 ]
#    ...
#    [0.80780756 0.81172913 0.7881997 ]
#    [0.8013941  0.8053157  0.78178626]
#    [0.7896957  0.7936173  0.77008784]]]], shape=(32, 128, 128, 3), dtype=float32)

# %%
# Data Augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical", input_shape=(128, 128, 3)),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.RandomContrast(0.2),
    tf.keras.layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model = tf.keras.Sequential()

model.add(data_augmentation)

# Convolutional layers
model.add(tf.keras.layers.Conv2D(64, kernel_size=3, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D())

model.add(tf.keras.layers.Conv2D(128, kernel_size=3, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D())

model.add(tf.keras.layers.Conv2D(256, kernel_size=3, padding='same', activation='relu'))
model.add(tf.keras.layers.MaxPooling2D())

model.add(tf.keras.layers.Dropout(0.3))

# Flatten and dense layers
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512, activation='relu'))

model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.3))

model.add(tf.keras.layers.Dense(256, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 128, 128, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 64, 64, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 32, 32, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 65536)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 512)                 │      33,554,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 34,059,393 (129.93 MB)
#  Trainable params: 34,058,369 (129.92 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

# %%
history = model.fit(train_data,
                    epochs=50,
                    validation_data=validation_data)
# Out:
# Epoch 1/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 22s 85ms/step - accuracy: 0.5134 - loss: 0.7790 - val_accuracy: 0.5300 - val_loss: 0.7828
# Epoch 2/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.5533 - loss: 0.7262 - val_accuracy: 0.5088 - val_loss: 1.2044
# Epoch 3/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 82ms/step - accuracy: 0.5542 - loss: 0.7052 - val_accuracy: 0.5125 - val_loss: 0.9905
# Epoch 4/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.6020 - loss: 0.6656 - val_accuracy: 0.5950 - val_loss: 0.6913
# Epoch 5/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 81ms/step - accuracy: 0.6185 - loss: 0.6443 - val_accuracy: 0.6500 - val_loss: 0.6373
# Epoch 6/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.6340 - loss: 0.6369 - val_accuracy: 0.6025 - val_loss: 0.7009
# Epoch 7/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 82ms/step - accuracy: 0.6526 - loss: 0.6263 - val_accuracy: 0.6413 - val_loss: 0.6203
# Epoch 8/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 19s 84ms/step - accuracy: 0.6547 - loss: 0.6207 - val_accuracy: 0.6162 - val_loss: 0.6843
# Epoch 9/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.6744 - loss: 0.6018 - val_accuracy: 0.5038 - val_loss: 1.3152
# Epoch 10/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 18s 81ms/step - accuracy: 0.6623 - loss: 0.6067 - val_accuracy: 0.5163 - val_loss: 0.7640
# Epoch 11/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 19s 83ms/step - accuracy: 0.6778 - loss: 0.6039 - val_accuracy: 0.6200 - val_loss: 0.6490
# Epoch 12/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.6761 - loss: 0.5921 - val_accuracy: 0.7038 - val_loss: 0.5771
# Epoch 13/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 19s 84ms/step - accuracy: 0.6864 - loss: 0.5843 - val_accuracy: 0.7163 - val_loss: 0.5504
# Epoch 14/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 18s 81ms/step - accuracy: 0.6926 - loss: 0.5819 - val_accuracy: 0.7175 - val_loss: 0.5586
# Epoch 15/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.6982 - loss: 0.5761 - val_accuracy: 0.7175 - val_loss: 0.5566
# Epoch 16/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.6937 - loss: 0.5752 - val_accuracy: 0.5675 - val_loss: 0.6775
# Epoch 17/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 82ms/step - accuracy: 0.7022 - loss: 0.5752 - val_accuracy: 0.6875 - val_loss: 0.5697
# Epoch 18/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.7093 - loss: 0.5623 - val_accuracy: 0.5788 - val_loss: 0.6596
# Epoch 19/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.7023 - loss: 0.5732 - val_accuracy: 0.6200 - val_loss: 0.6707
# Epoch 20/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.7067 - loss: 0.5641 - val_accuracy: 0.6812 - val_loss: 0.5942
# Epoch 21/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 19s 83ms/step - accuracy: 0.7103 - loss: 0.5633 - val_accuracy: 0.6350 - val_loss: 0.6413
# Epoch 22/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 18s 80ms/step - accuracy: 0.7036 - loss: 0.5648 - val_accuracy: 0.7500 - val_loss: 0.5132
# Epoch 23/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 82ms/step - accuracy: 0.7030 - loss: 0.5582 - val_accuracy: 0.7375 - val_loss: 0.5349
# Epoch 24/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 18s 80ms/step - accuracy: 0.7036 - loss: 0.5585 - val_accuracy: 0.7337 - val_loss: 0.5252
# Epoch 25/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 18s 81ms/step - accuracy: 0.7142 - loss: 0.5504 - val_accuracy: 0.7538 - val_loss: 0.5142
# Epoch 26/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.7164 - loss: 0.5499 - val_accuracy: 0.7600 - val_loss: 0.4981
# Epoch 27/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.7238 - loss: 0.5373 - val_accuracy: 0.6050 - val_loss: 0.6849
# Epoch 28/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 18s 81ms/step - accuracy: 0.7219 - loss: 0.5384 - val_accuracy: 0.7425 - val_loss: 0.5110
# Epoch 29/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.7358 - loss: 0.5314 - val_accuracy: 0.7300 - val_loss: 0.5283
# Epoch 30/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.7326 - loss: 0.5320 - val_accuracy: 0.7538 - val_loss: 0.4995
# Epoch 31/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 82ms/step - accuracy: 0.7327 - loss: 0.5329 - val_accuracy: 0.7437 - val_loss: 0.5010
# Epoch 32/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.7346 - loss: 0.5350 - val_accuracy: 0.7300 - val_loss: 0.5333
# Epoch 33/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 84ms/step - accuracy: 0.7413 - loss: 0.5191 - val_accuracy: 0.7437 - val_loss: 0.5276
# Epoch 34/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.7399 - loss: 0.5271 - val_accuracy: 0.7175 - val_loss: 0.5512
# Epoch 35/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.7404 - loss: 0.5294 - val_accuracy: 0.7175 - val_loss: 0.5311
# Epoch 36/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.7248 - loss: 0.5391 - val_accuracy: 0.7125 - val_loss: 0.5445
# Epoch 37/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 19s 82ms/step - accuracy: 0.7409 - loss: 0.5195 - val_accuracy: 0.7262 - val_loss: 0.5490
# Epoch 38/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 18s 81ms/step - accuracy: 0.7341 - loss: 0.5335 - val_accuracy: 0.6913 - val_loss: 0.6183
# Epoch 39/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 19s 83ms/step - accuracy: 0.7307 - loss: 0.5341 - val_accuracy: 0.6425 - val_loss: 0.6284
# Epoch 40/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 81ms/step - accuracy: 0.7345 - loss: 0.5179 - val_accuracy: 0.7275 - val_loss: 0.5026
# Epoch 41/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 81ms/step - accuracy: 0.7481 - loss: 0.5130 - val_accuracy: 0.7337 - val_loss: 0.5269
# Epoch 42/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 18s 80ms/step - accuracy: 0.7448 - loss: 0.5122 - val_accuracy: 0.7075 - val_loss: 0.5368
# Epoch 43/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 19s 83ms/step - accuracy: 0.7505 - loss: 0.5140 - val_accuracy: 0.7675 - val_loss: 0.4767
# Epoch 44/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.7543 - loss: 0.5111 - val_accuracy: 0.7588 - val_loss: 0.4926
# Epoch 45/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.7582 - loss: 0.5010 - val_accuracy: 0.7550 - val_loss: 0.4865
# Epoch 46/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 18s 82ms/step - accuracy: 0.7435 - loss: 0.5068 - val_accuracy: 0.6562 - val_loss: 0.6169
# Epoch 47/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 21s 83ms/step - accuracy: 0.7623 - loss: 0.4916 - val_accuracy: 0.7675 - val_loss: 0.4767
# Epoch 48/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - accuracy: 0.7535 - loss: 0.4953 - val_accuracy: 0.7375 - val_loss: 0.5178
# Epoch 49/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 19s 83ms/step - accuracy: 0.7651 - loss: 0.4928 - val_accuracy: 0.7400 - val_loss: 0.5164
# Epoch 50/50
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 18s 82ms/step - accuracy: 0.7568 - loss: 0.4965 - val_accuracy: 0.7625 - val_loss: 0.4941

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend()
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend()
plt.show()

# %% [markdown]
# # **Model Evaluation**

# %%
precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
accuracy = tf.keras.metrics.BinaryAccuracy()

# %%
for batch in test_data.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    precision.update_state(y, yhat)
    recall.update_state(y, yhat)
    accuracy.update_state(y, yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step

# %%
precision.result().numpy(), recall.result().numpy(), accuracy.result().numpy()
# Out:
# (0.7533461, 0.7786561, 0.76173997)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)

# %%
import cv2

# %%
image = cv2.imread('/content/cat-and-dog/test_set/test_set/cats/cat.4330.jpg')
plt.imshow(image)
plt.show()

# %%
resized_image = tf.image.resize(image, Image_size)
scaled_image = resized_image/255

# %%
scaled_image
# Out:
# <tf.Tensor: shape=(128, 128, 3), dtype=float32, numpy=
# array([[[0.805509  , 0.78197956, 0.6682541 ],
#         [0.8158701 , 0.7923407 , 0.6786152 ],
#         [0.8185336 , 0.7950042 , 0.6812787 ],
#         ...,
#         [0.6981005 , 0.6745711 , 0.5608456 ],
#         [0.69411767, 0.67058825, 0.5568628 ],
#         [0.7060049 , 0.6550245 , 0.52953434]],
#
#        [[0.79368395, 0.77015454, 0.65642905],
#         [0.81930625, 0.79577684, 0.68205136],
#         [0.813039  , 0.7895096 , 0.6757841 ],
#         ...,
#         [0.71395814, 0.69042873, 0.57670325],
#         [0.6981053 , 0.67457587, 0.5608504 ],
#         [0.7021446 , 0.6590074 , 0.5413603 ]],
#
#        [[0.7872099 , 0.7636805 , 0.649955  ],
#         [0.81506205, 0.79153264, 0.67780715],
#         [0.8306583 , 0.8071289 , 0.6934034 ],
#         ...,
#         [0.7226103 , 0.6990809 , 0.5853554 ],
#         [0.7002451 , 0.6767157 , 0.5629902 ],
#         [0.71341914, 0.6702819 , 0.5604779 ]],
#
#        ...,
#
#        [[0.20570332, 0.25919595, 0.27273762],
#         [0.27797756, 0.32080844, 0.3300609 ],
#         [0.02514265, 0.0447505 , 0.04658873],
#         ...,
#         [0.24581322, 0.32816616, 0.3595387 ],
#         [0.27170363, 0.35405657, 0.3854291 ],
#         [0.30379903, 0.3858456 , 0.39460784]],
#
#        [[0.18505189, 0.2324123 , 0.25547352],
#         [0.31606445, 0.35918733, 0.37457204],
#         [0.02843137, 0.05627393, 0.05735294],
#         ...,
#         [0.25485313, 0.34193665, 0.38154393],
#         [0.26397058, 0.34392902, 0.38248506],
#         [0.26617646, 0.35226715, 0.37132353]],
#
#        [[0.15598288, 0.18484318, 0.22442651],
#         [0.1395077 , 0.1868729 , 0.21542682],
#         [0.05080423, 0.09473805, 0.11042432],
#         ...,
#         [0.28386852, 0.38215286, 0.42817   ],
#         [0.2941569 , 0.35831133, 0.4092917 ],
#         [0.30045667, 0.39457434, 0.44163316]]], dtype=float32)>

# %%
np.expand_dims(scaled_image,0).shape
# Out:
# (1, 128, 128, 3)

# %%
y_hat = model.predict(np.expand_dims(scaled_image,0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
y_hat
# Out:
# array([[0.10934963]], dtype=float32)

# %%
class_names
# Out:
# ['cats', 'dogs']

# %%
if y_hat > 0.5:
    print(f'Predicted class is Dog')
else:
    print(f'Predicted class is Cat')
# Out:
# Predicted class is Cat
